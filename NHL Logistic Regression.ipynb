# %% [markdown]
# # Group 3 NHL Data Analytics Project

# %% [markdown]
# # Predicting event based on puck location and rink side

# %% [markdown]
# ### Load the dataset and select the appropriate fields

# %%
plays = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/team_3/nhl/playss.csv').dropna()
plays_side = plays.select('x','y','event','rink_side')
display(plays_side)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>x</th><th>y</th><th>event</th><th>rink_side</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td></tr><tr><td>28</td><td>24</td><td>Giveaway</td><td>right</td></tr><tr><td>52</td><td>28</td><td>Blocked Shot</td><td>right</td></tr><tr><td>80</td><td>-3</td><td>Shot</td><td>left</td></tr><tr><td>-30</td><td>-38</td><td>Hit</td><td>left</td></tr><tr><td>-60</td><td>39</td><td>Giveaway</td><td>right</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td></tr><tr><td>88</td><td>-4</td><td>Shot</td><td>left</td></tr><tr><td>81</td><td>-27</td><td>Shot</td><td>left</td></tr><tr><td>-64</td><td>-35</td><td>Hit</td><td>right</td></tr><tr><td>97</td><td>-9</td><td>Giveaway</td><td>right</td></tr><tr><td>73</td><td>11</td><td>Goal</td><td>left</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>left</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>right</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td></tr><tr><td>14</td><td>-32</td><td>Takeaway</td><td>left</td></tr><tr><td>63</td><td>-19</td><td>Shot</td><td>left</td></tr><tr><td>68</td><td>1</td><td>Shot</td><td>left</td></tr><tr><td>87</td><td>6</td><td>Giveaway</td><td>right</td></tr><tr><td>84</td><td>10</td><td>Shot</td><td>left</td></tr><tr><td>90</td><td>37</td><td>Hit</td><td>left</td></tr><tr><td>29</td><td>-31</td><td>Takeaway</td><td>left</td></tr><tr><td>65</td><td>-21</td><td>Shot</td><td>left</td></tr><tr><td>69</td><td>-22</td><td>Faceoff</td><td>left</td></tr><tr><td>74</td><td>-27</td><td>Missed Shot</td><td>left</td></tr><tr><td>52</td><td>39</td><td>Shot</td><td>left</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td></tr><tr><td>53</td><td>10</td><td>Blocked Shot</td><td>right</td></tr><tr><td>46</td><td>-17</td><td>Blocked Shot</td><td>right</td></tr><tr><td>67</td><td>-32</td><td>Shot</td><td>left</td></tr><tr><td>69</td><td>-22</td><td>Faceoff</td><td>right</td></tr><tr><td>87</td><td>-40</td><td>Hit</td><td>left</td></tr><tr><td>-28</td><td>-36</td><td>Hit</td><td>right</td></tr><tr><td>79</td><td>41</td><td>Hit</td><td>right</td></tr><tr><td>63</td><td>23</td><td>Shot</td><td>left</td></tr><tr><td>61</td><td>18</td><td>Blocked Shot</td><td>right</td></tr><tr><td>-20</td><td>-22</td><td>Faceoff</td><td>right</td></tr><tr><td>-24</td><td>17</td><td>Shot</td><td>right</td></tr><tr><td>-5</td><td>39</td><td>Penalty</td><td>left</td></tr><tr><td>-69</td><td>-22</td><td>Faceoff</td><td>left</td></tr><tr><td>-88</td><td>12</td><td>Shot</td><td>left</td></tr><tr><td>-82</td><td>-12</td><td>Blocked Shot</td><td>left</td></tr><tr><td>-75</td><td>-22</td><td>Blocked Shot</td><td>left</td></tr><tr><td>-69</td><td>-4</td><td>Blocked Shot</td><td>left</td></tr><tr><td>97</td><td>-23</td><td>Hit</td><td>left</td></tr><tr><td>97</td><td>7</td><td>Hit</td><td>left</td></tr><tr><td>-83</td><td>-22</td><td>Shot</td><td>right</td></tr><tr><td>-80</td><td>-14</td><td>Shot</td><td>right</td></tr><tr><td>-69</td><td>-22</td><td>Faceoff</td><td>left</td></tr><tr><td>-12</td><td>38</td><td>Hit</td><td>left</td></tr><tr><td>-54</td><td>-21</td><td>Shot</td><td>right</td></tr><tr><td>-29</td><td>-13</td><td>Shot</td><td>right</td></tr><tr><td>10</td><td>-25</td><td>Takeaway</td><td>left</td></tr><tr><td>79</td><td>12</td><td>Shot</td><td>left</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>left</td></tr><tr><td>-93</td><td>35</td><td>Hit</td><td>right</td></tr><tr><td>-14</td><td>-38</td><td>Hit</td><td>right</td></tr><tr><td>-55</td><td>-38</td><td>Shot</td><td>right</td></tr><tr><td>-69</td><td>-22</td><td>Faceoff</td><td>right</td></tr><tr><td>-20</td><td>-22</td><td>Faceoff</td><td>right</td></tr><tr><td>20</td><td>22</td><td>Faceoff</td><td>left</td></tr><tr><td>96</td><td>22</td><td>Hit</td><td>right</td></tr><tr><td>47</td><td> ...

# %% [markdown]
# ### Create rink side as an integer

# %%
from pyspark.sql.functions import *
plays_selected=plays_side.withColumn('s', when(col('rink_side') == ('left'), 0).when(col('rink_side') == ('right'), 1))
display(plays_selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>x</th><th>y</th><th>event</th><th>rink_side</th><th>s</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>28</td><td>24</td><td>Giveaway</td><td>right</td><td>1</td></tr><tr><td>52</td><td>28</td><td>Blocked Shot</td><td>right</td><td>1</td></tr><tr><td>80</td><td>-3</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>-30</td><td>-38</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>-60</td><td>39</td><td>Giveaway</td><td>right</td><td>1</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>88</td><td>-4</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>81</td><td>-27</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>-64</td><td>-35</td><td>Hit</td><td>right</td><td>1</td></tr><tr><td>97</td><td>-9</td><td>Giveaway</td><td>right</td><td>1</td></tr><tr><td>73</td><td>11</td><td>Goal</td><td>left</td><td>0</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>14</td><td>-32</td><td>Takeaway</td><td>left</td><td>0</td></tr><tr><td>63</td><td>-19</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>68</td><td>1</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>87</td><td>6</td><td>Giveaway</td><td>right</td><td>1</td></tr><tr><td>84</td><td>10</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>90</td><td>37</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>29</td><td>-31</td><td>Takeaway</td><td>left</td><td>0</td></tr><tr><td>65</td><td>-21</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>69</td><td>-22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>74</td><td>-27</td><td>Missed Shot</td><td>left</td><td>0</td></tr><tr><td>52</td><td>39</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>53</td><td>10</td><td>Blocked Shot</td><td>right</td><td>1</td></tr><tr><td>46</td><td>-17</td><td>Blocked Shot</td><td>right</td><td>1</td></tr><tr><td>67</td><td>-32</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>69</td><td>-22</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>87</td><td>-40</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>-28</td><td>-36</td><td>Hit</td><td>right</td><td>1</td></tr><tr><td>79</td><td>41</td><td>Hit</td><td>right</td><td>1</td></tr><tr><td>63</td><td>23</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>61</td><td>18</td><td>Blocked Shot</td><td>right</td><td>1</td></tr><tr><td>-20</td><td>-22</td><td>Faceoff</td><td>right</td><td>1</td></tr><tr><td>-24</td><td>17</td><td>Shot</td><td>right</td><td>1</td></tr><tr><td>-5</td><td>39</td><td>Penalty</td><td>left</td><td>0</td></tr><tr><td>-69</td><td>-22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>-88</td><td>12</td><td>Shot</td><td>left</td><td>0</td></tr><tr><td>-82</td><td>-12</td><td>Blocked Shot</td><td>left</td><td>0</td></tr><tr><td>-75</td><td>-22</td><td>Blocked Shot</td><td>left</td><td>0</td></tr><tr><td>-69</td><td>-4</td><td>Blocked Shot</td><td>left</td><td>0</td></tr><tr><td>97</td><td>-23</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>97</td><td>7</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>-83</td><td>-22</td><td>Shot</td><td>right</td><td>1</td></tr><tr><td>-80</td><td>-14</td><td>Shot</td><td>right</td><td>1</td></tr><tr><td>-69</td><td>-22</td><td>Faceoff</td><td>left</td><td>0</td></tr><tr><td>-12</td><td>38</td><td>Hit</td><td>left</td><td>0</td></tr><tr><td>-54</td><td>-21</td><td>Shot</td><td>right</td><td>1</td></tr><tr><td>-29</td><td>-13</td><td>Shot</td><td>right</td><td>1</td></tr><tr><td>10</td><td>-25</td><td>Takeaway</td><td>left</td><td>0</td></tr><tr><td ...

# %% [markdown]
# ### drop nulls

# %%
playsDF=plays_selected.dropna()
playsDF.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+--------+---------+---+
#   x|  y|   event|rink_side|  s|
# +---+---+--------+---------+---+
#   0|  0| Faceoff|    right|  1|
#  28| 24|Giveaway|    right|  1|
# +---+---+--------+---------+---+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### Count and show the number of events

# %%
playsDF.groupBy('event').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------+
#        event| count|
# +------------+------+
#         Goal| 16502|
#         Shot|169115|
#     Takeaway| 41304|
#  Missed Shot| 72888|
# Blocked Shot| 91172|
#     Giveaway| 51756|
#      Penalty| 24678|
#      Faceoff|189778|
#          Hit|160122|
# +------------+------+
#
# </div>

# %%
playsDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 817315</div>

# %% [markdown]
# ### show the schema

# %%
playsDF.cache()
playsDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- x: integer (nullable = true)
# -- y: integer (nullable = true)
# -- event: string (nullable = true)
# -- rink_side: string (nullable = true)
# -- s: integer (nullable = true)
#
# </div>

# %% [markdown]
# ### vector assembly, create a features column with X, Y, and the integer for rink side

# %%
from pyspark.ml.feature import VectorAssembler

vectorAssembler = VectorAssembler(inputCols = ['x','y','s'], outputCol = 'features')

playside_df = vectorAssembler.transform(playsDF)

playside_df.select(['features', 'event']).show(10, False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+------------+
# features         |event       |
# +-----------------+------------+
# [0.0,0.0,1.0]    |Faceoff     |
# [28.0,24.0,1.0]  |Giveaway    |
# [52.0,28.0,1.0]  |Blocked Shot|
# [80.0,-3.0,0.0]  |Shot        |
# [-30.0,-38.0,0.0]|Hit         |
# [-60.0,39.0,1.0] |Giveaway    |
# [0.0,0.0,1.0]    |Faceoff     |
# [88.0,-4.0,0.0]  |Shot        |
# [81.0,-27.0,0.0] |Shot        |
# [-64.0,-35.0,1.0]|Hit         |
# +-----------------+------------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### create a label column as event

# %%
from pyspark.ml.feature import StringIndexer

labelIndex = StringIndexer().setInputCol('event').setOutputCol('label')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### fit the dataset and drop any nulls (again, just in case)

# %%
label_DF = labelIndex.fit(playside_df).transform(playside_df).dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(label_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>x</th><th>y</th><th>event</th><th>rink_side</th><th>s</th><th>features</th><th>label</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td><td>List(1, 3, List(), List(0.0, 0.0, 1.0))</td><td>0.0</td></tr><tr><td>28</td><td>24</td><td>Giveaway</td><td>right</td><td>1</td><td>List(1, 3, List(), List(28.0, 24.0, 1.0))</td><td>5.0</td></tr><tr><td>52</td><td>28</td><td>Blocked Shot</td><td>right</td><td>1</td><td>List(1, 3, List(), List(52.0, 28.0, 1.0))</td><td>3.0</td></tr><tr><td>80</td><td>-3</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(80.0, -3.0, 0.0))</td><td>1.0</td></tr><tr><td>-30</td><td>-38</td><td>Hit</td><td>left</td><td>0</td><td>List(1, 3, List(), List(-30.0, -38.0, 0.0))</td><td>2.0</td></tr><tr><td>-60</td><td>39</td><td>Giveaway</td><td>right</td><td>1</td><td>List(1, 3, List(), List(-60.0, 39.0, 1.0))</td><td>5.0</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td><td>List(1, 3, List(), List(0.0, 0.0, 1.0))</td><td>0.0</td></tr><tr><td>88</td><td>-4</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(88.0, -4.0, 0.0))</td><td>1.0</td></tr><tr><td>81</td><td>-27</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(81.0, -27.0, 0.0))</td><td>1.0</td></tr><tr><td>-64</td><td>-35</td><td>Hit</td><td>right</td><td>1</td><td>List(1, 3, List(), List(-64.0, -35.0, 1.0))</td><td>2.0</td></tr><tr><td>97</td><td>-9</td><td>Giveaway</td><td>right</td><td>1</td><td>List(1, 3, List(), List(97.0, -9.0, 1.0))</td><td>5.0</td></tr><tr><td>73</td><td>11</td><td>Goal</td><td>left</td><td>0</td><td>List(1, 3, List(), List(73.0, 11.0, 0.0))</td><td>8.0</td></tr><tr><td>0</td><td>0</td><td>Faceoff</td><td>right</td><td>1</td><td>List(1, 3, List(), List(0.0, 0.0, 1.0))</td><td>0.0</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td><td>List(1, 3, List(), List(-69.0, 22.0, 0.0))</td><td>0.0</td></tr><tr><td>-69</td><td>22</td><td>Faceoff</td><td>right</td><td>1</td><td>List(1, 3, List(), List(-69.0, 22.0, 1.0))</td><td>0.0</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td><td>List(1, 3, List(), List(69.0, 22.0, 0.0))</td><td>0.0</td></tr><tr><td>14</td><td>-32</td><td>Takeaway</td><td>left</td><td>0</td><td>List(1, 3, List(), List(14.0, -32.0, 0.0))</td><td>6.0</td></tr><tr><td>63</td><td>-19</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(63.0, -19.0, 0.0))</td><td>1.0</td></tr><tr><td>68</td><td>1</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(68.0, 1.0, 0.0))</td><td>1.0</td></tr><tr><td>87</td><td>6</td><td>Giveaway</td><td>right</td><td>1</td><td>List(1, 3, List(), List(87.0, 6.0, 1.0))</td><td>5.0</td></tr><tr><td>84</td><td>10</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(84.0, 10.0, 0.0))</td><td>1.0</td></tr><tr><td>90</td><td>37</td><td>Hit</td><td>left</td><td>0</td><td>List(1, 3, List(), List(90.0, 37.0, 0.0))</td><td>2.0</td></tr><tr><td>29</td><td>-31</td><td>Takeaway</td><td>left</td><td>0</td><td>List(1, 3, List(), List(29.0, -31.0, 0.0))</td><td>6.0</td></tr><tr><td>65</td><td>-21</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(65.0, -21.0, 0.0))</td><td>1.0</td></tr><tr><td>69</td><td>-22</td><td>Faceoff</td><td>left</td><td>0</td><td>List(1, 3, List(), List(69.0, -22.0, 0.0))</td><td>0.0</td></tr><tr><td>74</td><td>-27</td><td>Missed Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(74.0, -27.0, 0.0))</td><td>4.0</td></tr><tr><td>52</td><td>39</td><td>Shot</td><td>left</td><td>0</td><td>List(1, 3, List(), List(52.0, 39.0, 0.0))</td><td>1.0</td></tr><tr><td>69</td><td>22</td><td>Faceoff</td><td>left</td><td>0</td><td>List(1, 3, List(), List(69.0, 22.0, 0.0))</td><td>0.0</td></tr><tr><td>53</td><td>10</td><td>Blocked Shot</td><td>right</td><td>1</td><td>Lis ...

# %% [markdown]
# ### split the new data into testing and training datasets

# %%
(atrain, atest) = label_DF.randomSplit([0.7, 0.3], seed=100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### run logistic regression

# %%
from pyspark.ml.classification import *

log = LogisticRegression(featuresCol = 'features', labelCol='label', maxIter=10, regParam=0.3, elasticNetParam=0.8)
log_model = log.fit(atrain)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### show the prediction

# %%
logPrediction=log_model.transform(atest)
logPrediction.select("label", "prediction").show(10, False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+
# label|prediction|
# +-----+----------+
# 2.0  |0.0       |
# 2.0  |0.0       |
# 2.0  |0.0       |
# 5.0  |0.0       |
# 5.0  |0.0       |
# 2.0  |0.0       |
# 2.0  |0.0       |
# 2.0  |0.0       |
# 2.0  |0.0       |
# 5.0  |0.0       |
# +-----+----------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### calculate the prediction accuracy

# %%
print("prediction accuracy is: ", logPrediction.where("prediction==label").count()/logPrediction.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">prediction accuracy is:  0.2326716338261114
# </div>

# %% [markdown]
# # The prediction accuracy is very low at 23.2%
# ## Meaning puck location and rink side are not indiciative of the event that will happen

# %% [markdown]
# # Prediction accuracy increased from 23.07% to 23.2% when rink side was added in

# %% [markdown]
# # Cross Validation

# %%
# instantiate a logistic Regression model
from pyspark.ml.classification import LogisticRegression

lr= LogisticRegression()

 # Create ParamGrid for Cross Validation
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.01, 0.1, 2])
             .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])
             .addGrid(lr.maxIter, [5, 10])
             .build())

#define evaluator
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator = BinaryClassificationEvaluator()\
  .setMetricName("areaUnderROC")\
  .setRawPredictionCol("prediction")\
  .setLabelCol("label")

# Create 2-fold CrossValidator
cv_lr = CrossValidator(estimator=lr, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=2)

# Run cross validations. 
# this will likely take a fair amount of time because of the amount of models that we're creating and testing. 
# It takes 3 minutes to run this model.
cv_lrModel = cv_lr.fit(atrain)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
# Use test set to measure the accuracy of our model on new data
cv_lrPrediction = cv_lrModel.transform(atest)

# cvModel uses the best model found from the Cross Validation
# Evaluate best model
evaluator.evaluate(cv_lrPrediction)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 0.5</div>

# %%
# Calculate accuracy

print("prediction accuracy is: ", cv_lrPrediction.where("prediction==label").count()/cv_lrPrediction.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">prediction accuracy is:  0.2326716338261114
# </div>

# %% [markdown]
# # Cross Validation did NOT improve the model at all.
